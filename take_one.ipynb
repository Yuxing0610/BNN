# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import numpy as np
import torchvision
from torchvision import transforms
import matplotlib as plt
import cmath

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cpu')
    else:
        return torch.device('cpu')
DEVICE = get_default_device()
print(DEVICE)
# Out:
# cpu

# %%
def switch_to_device(dataset, device = None):
    tensor_list_x, tensor_list_y = [], []

    for x, y in dataset:
        tensor_list_x.append(x)
        tensor_list_y.append(y)
    
    X = torch.stack(tensor_list_x)
    Y = torch.tensor(tensor_list_y)

    if DEVICE is not None:
        X = X.to(DEVICE)
        Y = Y.to(DEVICE)
    
    return torch.utils.data.TensorDataset(X, Y)

# %%
def get_mnist_dl(batch_size_train = 256, batch_size_valid = 1024, device = None):
    transform = transforms.Compose([transforms.ToTensor()])

    data_train = torchvision.datasets.MNIST('./mnist', train = True, download = True, transform = transform)
    data_train = switch_to_device(data_train, device)
    data_train, data_valid = torch.utils.data.random_split(data_train, [55000, 5000])

    data_test = torchvision.datasets.MNIST('./mnist', train = False, download = True, transform = transform)
    data_test = switch_to_device(data_test, device)

    train_dl = DataLoader(data_train, batch_size=batch_size_train, shuffle=True)
    valid_dl = DataLoader(data_valid, batch_size=batch_size_valid, shuffle=False)
    test_dl = DataLoader(data_test, batch_size=batch_size_valid, shuffle=False)

    return train_dl, valid_dl, test_dl

# %%
def possibility_normalize(possi, non_zero_perc, slimness):
    mean = torch.mean(possi)
    std = torch.std(possi)
    if 999 <= mean <= 1001:
        new_possi = torch.full(possi.shape, non_zero_perc).to(possi.device)
    else:
        new_possi = ((possi - mean)/std*slimness) + non_zero_perc
        new_possi = torch.clip(new_possi, 0, 1)
    return new_possi

# %%
def delta_generation(possi):
    non_zero = torch.bernoulli(possi)
    possi_ = non_zero/2
    neg_pos = torch.bernoulli(possi_)
    res = non_zero - 2*neg_pos
    return res

# %%
def quantization(x, q_bits):
    q_max = 2 ** q_bits - 1
    x_max = torch.max(x)
    x_min = torch.min(x)
    q_x = q_max*(x - x_min)/(x_max - x_min)
    q_x = torch.round(q_x)
    return q_x

# %%
def q_f_multiplication(q_a, q_w, b_a, b_w):
    term_1 = 2*(torch.matmul(q_a, q_w))/((2 ** b_a - 1)*(2 ** b_w - 1))
    term_2 = torch.matmul(q_a, torch.ones(q_w.shape)) / (2 ** b_a - 1)
    return term_1 - term_2

# %%
class Relu():
    @torch.no_grad()
    def __init__(self, qa_flag = True, qa_bits = 2):
        self.qa_flag = qa_flag
        self.qa_bits = qa_bits

    @torch.no_grad()
    def forward(self, input):
        if self.qa_flag:
            q_input = quantization(input, self.qa_bits)
            res = (torch.abs(q_input) + q_input) / 2.0
        else:
            res = (torch.abs(input) + input) / 2.0
        return res

# %%
class Softmax_CrossEntropy():
    @torch.no_grad()
    def __init__(self, qa_flag, qo_flag, qa_bits, qo_bits):
        self.qa_flag = qa_flag
        self.qo_flag = qo_flag
        self.qa_bits = qa_bits
        self.qo_bits = qo_bits

    @torch.no_grad()
    def forward(self, input, labels):
        if self.qa_flag:
            input = quantization(input, self.qa_bits)
        
        max = input.max()
        min = input.min()
        input = (input-min)/(max-min)

        exp_z = torch.exp(input)
        sum_exp_z = torch.sum(exp_z, dim = 1).reshape(input.shape[0], 1)
        softmax_z = exp_z/sum_exp_z
        softmax_z += 1e-6
        
        if self.qo_flag:
            softmax_z = quantization(softmax_z, self.qo_bits)

        loss = torch.sum(-(labels*torch.log(softmax_z))) / input.shape[0]
        
        return loss

# %%
from functools import total_ordering
from torch import logical_not


class QLinear:
    @torch.no_grad()
    def __init__(self, input_num, output_num, qa_flag = True, qa_bits = 2, qw_bits = 2, qb_bits = 2, device = None):
        if device is None:
            print("Must have device")
            return
        self.device = device
        self.input_num, self.output_num = input_num, output_num
        self.qa_bits, self.qw_bits, self.qb_bits = qa_bits, qw_bits, qb_bits
        self.weights = torch.randint(0, 2**self.qw_bits, (self.input_num, self.output_num)).to(device)
        self.bias = torch.randint(0, 2**self.qb_bits, (1, self.output_num)).to(device)
        self.weights = self.weights.float()
        self.bias = self.bias.float()
        self.w_u = torch.zeros(self.input_num, self.output_num).to(device)
        self.b_u = torch.zeros(1, self.output_num).to(device)
        self.w_pickflag = torch.zeros(self.input_num, self.output_num).to(device)
        self.b_pickflag = torch.zeros(1, self.output_num).to(device)
        self.w_p = torch.full((self.input_num, self.output_num), 1000.).to(device)
        self.b_p = torch.full((1, self.output_num), 1000.).to(device)
        self.qa_flag = qa_flag
        #For debug purpose
        self.accumulate_pickw = torch.zeros(self.input_num, self.output_num).to(device)
        self.accumulate_pickb = torch.zeros(1, self.output_num).to(device)
    
    @torch.no_grad()
    def forward(self, input):
        self.w_u = torch.zeros(self.input_num, self.output_num).to(self.device)
        self.b_u = torch.zeros(1, self.output_num).to(self.device)
        self.w_p = torch.full((self.input_num, self.output_num), 1000.).to(self.device)
        self.b_p = torch.full((1, self.output_num), 1000.).to(self.device)
        self.w_pickflag = torch.zeros(self.input_num, self.output_num).to(self.device)
        self.b_pickflag = torch.zeros(1, self.output_num).to(self.device)
        #For debug purpose
        self.accumulate_pickw = torch.zeros(self.input_num, self.output_num).to(self.device)
        self.accumulate_pickb = torch.zeros(1, self.output_num).to(self.device)
        
        '''
        if self.qa_flag:
            q_input = quantization(input, self.qa_bits)
            res = torch.matmul(q_input, self.weights) + self.bias
        else:
            res = torch.matmul(input, self.weights) + self.bias
        '''
        if self.qa_flag:
            q_input = quantization(input, self.qa_bits)
            res = q_f_multiplication(q_input, self.weights, self.qa_bits, self.qw_bits) + (2*self.bias)/(2**self.qb_bits - 1) - 1
        else:
            res = torch.matmul(input, ((2*self.weights)/(2**self.qw_bits - 1) - 1)) + (2*self.bias)/(2**self.qb_bits - 1) - 1

        return res

    @torch.no_grad()
    def random_search(self, input, non_zero_percent):
        if non_zero_percent>0.5:
            slimness = 1-non_zero_percent
        else:
            slimness = non_zero_percent
            
        temp_wp = possibility_normalize(self.w_p, non_zero_perc=non_zero_percent, slimness=slimness)
        temp_bp = possibility_normalize(self.b_p, non_zero_perc=non_zero_percent, slimness=slimness)
        self.delta_matrix_w = delta_generation(temp_wp)
        self.delta_matrix_b = delta_generation(temp_bp)
        #for debug purpose
        self.accumulate_pickw += torch.abs(self.delta_matrix_w)

        temp_weights = torch.clip(self.weights + self.delta_matrix_w, 0, 2**(self.qw_bits) - 1)
        temp_bias = torch.clip(self.bias + self.delta_matrix_b, 0, 2**(self.qb_bits) - 1)

        self.delta_matrix_w = temp_weights - self.weights
        self.delta_matrix_b = temp_bias - self.bias
        '''
        if self.qa_flag:
            q_input = quantization(input, self.qa_bits)
            res = torch.matmul(q_input, temp_weights) + temp_bias
        else:
            res = torch.matmul(input, temp_weights) + temp_bias
        '''
        if self.qa_flag:
            q_input = quantization(input, self.qa_bits)
            res = q_f_multiplication(q_input, temp_weights, self.qa_bits, self.qw_bits) + (2*temp_bias)/(2**self.qb_bits - 1) - 1
        else:
            res = torch.matmul(input, ((2*temp_weights)/(2**self.qw_bits - 1) - 1)) + (2*temp_bias)/(2**self.qb_bits - 1) - 1

        return res

    @torch.no_grad()
    def mid_update(self, delta_loss):
        self.w_u = self.w_u + (delta_loss * self.delta_matrix_w)
        self.b_u = self.b_u + (delta_loss * self.delta_matrix_b)
        w_ptemp = torch.mul(self.w_pickflag, self.w_p)/(torch.ones(self.w_pickflag.shape).to(self.device) + torch.abs(self.delta_matrix_w)) + torch.abs(delta_loss) * torch.abs(self.delta_matrix_w)/(torch.ones(self.w_pickflag.shape).to(self.device) + self.w_pickflag)
        b_ptemp = torch.mul(self.b_pickflag, self.b_p)/(torch.ones(self.b_pickflag.shape).to(self.device) + torch.abs(self.delta_matrix_b)) + torch.abs(delta_loss) * torch.abs(self.delta_matrix_b)/(torch.ones(self.b_pickflag.shape).to(self.device) + self.b_pickflag)
        self.w_pickflag = (self.w_pickflag + torch.abs(self.delta_matrix_w)) > 0
        self.b_pickflag = (self.b_pickflag + torch.abs(self.delta_matrix_b)) > 0
        self.w_p = w_ptemp + 1000*logical_not(self.w_pickflag)
        self.b_p = b_ptemp + 1000*logical_not(self.b_pickflag)
    
    @torch.no_grad()
    def final_update(self, total_delta_loss, c):
        plus_matrix_w = torch.zeros(self.weights.shape).to(self.device)
        minus_matrix_w = torch.zeros(self.weights.shape).to(self.device)
        plus_matrix_w[self.w_u >= (c*total_delta_loss)] = 1
        minus_matrix_w[self.w_u <= -(c*total_delta_loss)] = -1
        '''
        print(self.w_u)
        print(total_delta_loss)
        print(plus_matrix_w)
        print(minus_matrix_w)
        print(self.weights)
        print(plus_matrix_w + minus_matrix_w)
        print(torch.count_nonzero(plus_matrix_w + minus_matrix_w))
        print(total_delta_loss)
        print(self.w_u.max(), self.w_u.min())
        print(self.accumulate_pickw.max(), self.accumulate_pickw.min())
        '''
        self.weights = self.weights + plus_matrix_w + minus_matrix_w
        plus_matrix_b = torch.zeros(self.bias.shape).to(self.device)
        minus_matrix_b = torch.zeros(self.bias.shape).to(self.device)
        plus_matrix_b[self.b_u >= (c*total_delta_loss)] = 1
        minus_matrix_b[self.b_u <= -(c*total_delta_loss)] = -1
        self.bias = self.bias + plus_matrix_b + minus_matrix_b

# %%
class MLP_BNN():
    def __init__(self, device = None):
        if device is None:
            print("Must have device")
            return
        else:
            self.device = device
        self.fc_1 = QLinear(input_num=28*28, output_num=512, qa_flag=False, qa_bits=3, qw_bits=3, qb_bits=3, device = device)
        self.Relu_1 = Relu(qa_flag=True, qa_bits=2)
        self.fc_2 = QLinear(input_num=512, output_num=512, qa_flag=True, qa_bits=3, qw_bits=3, qb_bits=3, device = device)
        self.Relu_2 = Relu(qa_flag=True, qa_bits=2)
        self.fc_3 = QLinear(input_num=512, output_num=10, qa_flag=True, qa_bits=3, qw_bits=3, qb_bits=3, device = device)
        self.CrossEntropy = Softmax_CrossEntropy(qa_flag=False, qa_bits=0, qo_flag=False, qo_bits=0)
        self.output = None
        self.loss_base = None
        self.total_delta_loss = 0
    
    def forward(self, input, labels, update_itr = 0):
        self.total_delta_loss = 0
        self.input = torch.reshape(input, (input.shape[0], 28*28))
        output = self.fc_1.forward(self.input)
        output = self.Relu_1.forward(output)
        output = self.fc_2.forward(output)
        output = self.Relu_2.forward(output)
        output = self.fc_3.forward(output)
        self.output = output
        self.loss_base = self.CrossEntropy.forward(output, labels)

        for i in range(update_itr):
            output = self.fc_1.random_search(self.input, non_zero_percent=0.3)
            output = self.Relu_1.forward(output)
            output = self.fc_2.random_search(output, non_zero_percent=0.3)
            output = self.Relu_2.forward(output)
            output = self.fc_3.random_search(output, non_zero_percent=0.3)
            loss = self.CrossEntropy.forward(output, labels)
            delta_loss = self.loss_base - loss
            print(delta_loss)
            self.total_delta_loss = self.total_delta_loss + torch.abs(delta_loss)
            self.fc_1.mid_update(delta_loss)
            self.fc_2.mid_update(delta_loss)
            self.fc_3.mid_update(delta_loss)
        

    def update(self):
        self.fc_1.final_update(self.total_delta_loss, 0.7)
        self.fc_2.final_update(self.total_delta_loss, 0.7)
        self.fc_3.final_update(self.total_delta_loss, 0.7)

# %%
def print_stats(stats):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (7, 3), dpi = 110)
    ax1.grid()
    ax2.grid()

    ax1.set_title("ERM loss")
    ax2.set_title("Valid Acc")

    ax1.setxlabel("iterations")
    ax2.setxlabel("iterations")

    itrs = [x[0] for x in stats['train-loss']]
    loss = [x[1] for x in stats['train-loss']]
    ax1.plot(itrs, loss)

    itrs = [x[0] for x in stats['valid-acc']]
    acc = [x[1] for x in stats['valid-acc']]
    ax2.plot(itrs, acc)

    ax1.set_ylim(0.0, 4.05)
    ax2.set_ylim(0.0, 1.05)

# %%
@torch.no_grad()
def get_acc(model, dl, device = DEVICE):
    acc = []

    for X, y in dl:
        one_hot_y = torch.zeros(X.shape[0], 10).to(device)
        one_hot_y[[i for i in range(X.shape[0])], [k.item() for k in y]] = 1
        model.forward(X, one_hot_y)
        acc.append(torch.argmax(model.output, dim = 1) == y)

    acc = torch.cat(acc)
    acc = torch.sum(acc)/len(acc)

    return acc.item()

# %%
def run_experiment(model, train_dl, valid_dl, test_dl, max_epochs=20, device=DEVICE):
    itr = -1
    stats = {'train-loss' : [], 'valid-acc' : []}
    for epoch in range(max_epochs):
        for X, y in train_dl:
            itr += 1
            one_hot_y = torch.zeros(X.shape[0], 10).to(device)
            one_hot_y[[i for i in range(X.shape[0])], [k.item() for k in y]] = 1
            model.forward(X, one_hot_y, 10)
            '''
            print(model.output)
            '''
            model.update()
            stats['train-loss'].append((itr, model.loss_base.item()))

            if itr != 0 and itr % 20 == 0:
                valid_acc = get_acc(model, valid_dl, device = device)
                stats['valid-acc'].append((itr, valid_acc))
                s = f"{epoch}:{itr} [train] loss:{model.loss_base.item():.3f}, [valid] acc:{valid_acc:.3f}"
                print(s)
    
    test_acc = get_acc(model, test_dl, device=device)
    print(f"[test] acc:{test_acc:.3f}")
    return stats

# %%
max_epochs = 20
train_batch = 256
valid_batch = 1024

# %%
train_dl, valid_dl, test_dl = get_mnist_dl(batch_size_train=train_batch, batch_size_valid=valid_batch, device = DEVICE)
model = MLP_BNN(device=DEVICE)
stats = run_experiment(model, train_dl, valid_dl, test_dl, max_epochs=max_epochs, device = DEVICE)
print_stats(stats)
# Out:
# tensor(-0.0094)
# tensor(0.0092)
# tensor(-0.0004)
# tensor(-0.0021)
# tensor(0.0015)
# tensor(-0.0031)
# tensor(0.0028)
# tensor(0.0075)
# tensor(0.0091)
# tensor(-0.0089)
# tensor(0.0018)
# tensor(-0.0043)
# tensor(-0.0020)
# tensor(0.0013)
# tensor(9.5367e-07)
# tensor(0.0063)
# tensor(0.0006)
# tensor(-0.0065)
# tensor(0.0038)
# tensor(0.0019)
# tensor(0.0001)
# tensor(-0.0028)
# tensor(0.0035)
# tensor(-0.0074)
# tensor(0.0032)
# tensor(0.0053)
# tensor(-0.0051)
# tensor(0.0043)
# tensor(0.0005)
# tensor(0.0020)
# tensor(0.0112)
# tensor(0.0172)
# tensor(0.0155)
# tensor(0.0053)
# tensor(0.0140)
# tensor(-0.0036)
# tensor(0.0060)
# tensor(-0.0105)
# tensor(0.0037)
# tensor(0.0136)
# tensor(-0.0082)
# tensor(-0.0054)
# tensor(0.0045)
# tensor(0.0039)
# tensor(0.0012)
# tensor(0.0034)
# tensor(-0.0042)
# tensor(-0.0121)
# tensor(0.0008)
# tensor(0.0002)
# tensor(0.0019)
# tensor(0.0092)
# tensor(0.0080)
# tensor(0.0170)
# tensor(0.0138)
# tensor(0.0112)
# tensor(-0.0026)
# tensor(0.0186)
# tensor(0.0161)
# tensor(0.0028)
# tensor(0.0097)
# tensor(0.0176)
# tensor(0.0049)
# tensor(0.0015)
# tensor(0.0012)
# tensor(0.0028)
# tensor(0.0014)
# tensor(0.0139)
# tensor(0.0043)
# tensor(-0.0056)
# tensor(0.0048)
# tensor(0.0100)
# tensor(-0.0019)
# tensor(0.0030)
# tensor(0.0065)
# tensor(-0.0009)
# tensor(-0.0080)
# tensor(-0.0121)
# tensor(-0.0080)
# tensor(0.0114)
# tensor(-0.0041)
# tensor(0.0045)
# tensor(0.0066)
# tensor(-9.5367e-05)
# tensor(0.0047)
# tensor(0.0059)
# tensor(0.0066)
# tensor(0.0113)
# tensor(0.0106)
# tensor(0.0035)
# tensor(0.0101)
# tensor(-0.0030)
# tensor(0.0025)
# tensor(-0.0072)
# tensor(-0.0036)
# tensor(-0.0008)
# tensor(0.0067)
# tensor(-0.0045)
# tensor(0.0034)
# tensor(-0.0023)
# tensor(-0.0013)
# tensor(-0.0078)
# tensor(-0.0100)
# tensor(-0.0077)
# tensor(0.0012)
# tensor(-0.0082)
# tensor(0.0073)
# tensor(0.0016)
# tensor(-0.0034)
# tensor(-0.0055)
# tensor(0.0027)
# tensor(-0.0096)
# tensor(0.0037)
# tensor(0.0064)
# tensor(-0.0006)
# tensor(-0.0007)
# tensor(0.0028)
# tensor(0.0042)
# tensor(0.0014)
# tensor(-0.0083)
# tensor(-0.0004)
# tensor(0.0047)
# tensor(-0.0069)
# tensor(0.0039)
# tensor(-0.0001)
# tensor(-0.0115)
# tensor(-0.0009)
# tensor(-0.0075)
# tensor(-0.0060)
# tensor(0.0006)
# tensor(0.0042)
# tensor(-0.0069)
# tensor(-0.0079)
# tensor(-0.0051)
# tensor(-0.0044)
# tensor(-0.0002)
# tensor(-0.0039)
# tensor(-0.0008)
# tensor(-0.0053)
# tensor(0.0034)
# tensor(0.0029)
# tensor(-0.0028)
# tensor(0.0043)
# tensor(0.0061)
# tensor(0.0039)
# tensor(-0.0012)
# tensor(-0.0002)
# tensor(-0.0029)
# tensor(-0.0026)
# tensor(-0.0011)
# tensor(7.4387e-05)
# tensor(-0.0022)
# tensor(0.0002)
# tensor(-0.0051)
# tensor(-0.0016)
# tensor(-0.0023)
# tensor(-0.0026)
# tensor(-0.0015)
# tensor(-0.0092)
# tensor(0.0072)
# tensor(-0.0005)
# tensor(-0.0022)
# tensor(0.0040)
# tensor(-0.0074)
# tensor(-0.0042)
# tensor(0.0011)
# tensor(-0.0034)
# tensor(0.0003)
# tensor(-0.0069)
# tensor(-0.0089)
# tensor(0.0014)
# tensor(-0.0041)
# tensor(0.0043)
# tensor(-0.0057)
# tensor(0.0003)
# tensor(-0.0054)
# tensor(-0.0065)
# tensor(-0.0035)
# tensor(-0.0003)
# tensor(-0.0033)
# tensor(0.0003)
# tensor(-0.0073)
# tensor(0.0018)
# tensor(-0.0030)
# tensor(-0.0058)
# tensor(5.4121e-05)
# tensor(-0.0098)
# tensor(-0.0061)
# tensor(-0.0020)
# tensor(-0.0016)
# tensor(-0.0097)
# tensor(-0.0152)
# tensor(-0.0055)
# tensor(-0.0068)
# tensor(-0.0111)
# tensor(-0.0065)
# tensor(-0.0052)
# tensor(-0.0156)
# tensor(-0.0081)
# tensor(-0.0022)
# tensor(-0.0044)
# tensor(-0.0044)
# tensor(-0.0212)
# 1:220 [train] loss:2.321, [valid] acc:0.118
# tensor(-0.0081)
# tensor(-0.0051)
# tensor(-0.0019)
# tensor(-0.0021)
# tensor(-0.0028)
# tensor(-0.0032)
# tensor(-0.0044)
# tensor(-0.0005)
# tensor(-0.0039)
# tensor(-0.0046)
# tensor(-0.0035)
# tensor(-0.0053)
# tensor(0.0034)
# tensor(-0.0116)
# tensor(-0.0229)
# tensor(-0.0035)
# tensor(-0.0074)
# tensor(-0.0163)
# tensor(-0.0128)
# tensor(-0.0072)
# tensor(-0.0104)
# tensor(-0.0047)
# tensor(-0.0142)
# tensor(-0.0068)
# tensor(-0.0128)
# tensor(-0.0101)
# tensor(-0.0124)
# tensor(-0.0072)
# tensor(0.0022)
# tensor(-0.0140)
# tensor(-0.0019)
# tensor(-0.0075)
# tensor(-0.0081)
# tensor(-0.0083)
# tensor(-0.0054)
# tensor(-0.0118)
# tensor(-0.0051)
# tensor(-0.0104)
# tensor(-0.0092)
# tensor(-0.0050)
# tensor(-0.0087)
# tensor(-0.0066)
# tensor(-0.0141)
# tensor(-0.0186)
# tensor(-0.0060)
# tensor(-0.0125)
# tensor(-0.0078)
# tensor(-0.0089)
# tensor(-0.0117)
# tensor(-0.0076)
# tensor(-0.0326)
# tensor(-0.0238)
# tensor(-0.0090)
# tensor(-0.0142)
# tensor(-0.0272)
# tensor(-0.0171)
# tensor(-0.0101)
# tensor(-0.0203)
# tensor(-0.0283)
# tensor(-0.0165)
# tensor(-0.0058)
# tensor(-0.0089)
# tensor(-0.0139)
# tensor(-0.0134)
# tensor(-0.0076)
# tensor(-0.0139)
# tensor(-0.0052)
# tensor(-0.0106)
# tensor(-0.0194)
# tensor(-0.0078)
# tensor(-0.0182)
# tensor(-0.0148)
# tensor(-0.0138)
# tensor(-0.0272)
# tensor(-0.0135)
# tensor(-0.0116)
# tensor(-0.0109)
# tensor(-0.0184)
# tensor(-0.0073)
# tensor(-0.0095)
# tensor(-0.0078)
# tensor(-0.0045)
# tensor(0.0008)
# tensor(-0.0010)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/deyaoyux/BNN/take_one.ipynb Cell 17 in <cell line: 3>()
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> train_dl, valid_dl, test_dl = get_mnist_dl(batch_size_train=train_batch, batch_size_valid=valid_batch, device = DEVICE)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> model = MLP_BNN(device=DEVICE)
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> stats = run_experiment(model, train_dl, valid_dl, test_dl, max_epochs=max_epochs, device = DEVICE)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> print_stats(stats)
#
# /home/deyaoyux/BNN/take_one.ipynb Cell 17 in run_experiment(model, train_dl, valid_dl, test_dl, max_epochs, device)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> one_hot_y = torch.zeros(X.shape[0], 10).to(device)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> one_hot_y[[i for i in range(X.shape[0])], [k.item() for k in y]] = 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> model.forward(X, one_hot_y, 10)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> '''
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> print(model.output)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> '''
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> model.update()
#
# /home/deyaoyux/BNN/take_one.ipynb Cell 17 in MLP_BNN.forward(self, input, labels, update_itr)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a> self.loss_base = self.CrossEntropy.forward(output, labels)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a> for i in range(update_itr):
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a>     output = self.fc_1.random_search(self.input, non_zero_percent=0.3)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a>     output = self.Relu_1.forward(output)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=31'>32</a>     output = self.fc_2.random_search(output, non_zero_percent=0.3)
#
# File ~/anaconda3/envs/test_env/lib/python3.9/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# /home/deyaoyux/BNN/take_one.ipynb Cell 17 in QLinear.random_search(self, input, non_zero_percent)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=62'>63</a> temp_wp = possibility_normalize(self.w_p, non_zero_perc=non_zero_percent, slimness=slimness)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=63'>64</a> temp_bp = possibility_normalize(self.b_p, non_zero_perc=non_zero_percent, slimness=slimness)
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=64'>65</a> self.delta_matrix_w = delta_generation(temp_wp)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=65'>66</a> self.delta_matrix_b = delta_generation(temp_bp)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=66'>67</a> #for debug purpose
#
# /home/deyaoyux/BNN/take_one.ipynb Cell 17 in delta_generation(possi)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> non_zero = torch.bernoulli(possi)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> possi_ = non_zero/2
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> neg_pos = torch.bernoulli(possi_)
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> res = non_zero - 2*neg_pos
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a226465737463307374726170703935222c2275736572223a22646579616f797578227d/home/deyaoyux/BNN/take_one.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> return res
#
# KeyboardInterrupt:
